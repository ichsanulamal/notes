# %%
from unstructured.partition.auto import partition

# %%
elements = partition(filename="books/1998.epub")

# %%
for i in elements:
    print(i)
# Out:
# The Project
# Gutenberg eBook of Thus Spake Zarathustra: A Book for All and None
#
# This ebook is for the use of anyone anywhere in the United States and
# most other parts of the world at no cost and with almost no restrictions
# whatsoever. You may copy it, give it away or re-use it under the terms
# of the Project Gutenberg License included with this ebook or online at
#
# www.gutenberg.org. If you are not located
# in the United States, you will have to check the laws of the country
# where you are located before using this eBook.
# Title: Thus Spake Zarathustra: A Book for All and
# None
# Author: Friedrich Wilhelm Nietzsche
# Translator: Thomas Common
# Release date: December 1, 1999 [eBook #1998]
# Most recently updated: April 10, 2023
# Language: English
# Credits: Sue Asscher and David Widger
# Revised by Richard Tonsing.
# *** START OF THE PROJECT GUTENBERG EBOOK THUS SPAKE ZARATHUSTRA: A
# BOOK FOR ALL AND NONE ***
# THUS SPAKE
# ZARATHUSTRA
# A BOOK FOR ALL AND NONE
# ...
