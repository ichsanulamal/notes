# %%
# Import Module
from bs4 import *
import requests

# Given URL
url = "https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia"

# Fetch URL Content
r = requests.get(url)

# Get body content
soup = BeautifulSoup(r.text,'html.parser').select('body')[0]

# Initialize variable
paragraphs = []
images = []
link = []
heading = []
remaining_content = []

# Iterate through all tags
for tag in soup.find_all():
	
	# Check each tag name
	# For Paragraph use p tag
	if tag.name=="p":
	
		# use text for fetch the content inside p tag
		paragraphs.append(tag.text)
		
	# For Image use img tag
	elif tag.name=="img":
	
		# Add url and Image source URL
		images.append(url+tag['src'])
		
	# For Anchor use a tag
	elif tag.name=="a":
	
		# convert into string and then check href
		# available in tag or not
		if "href" in str(tag):
		
		# In href, there might be possible url is not there
		# if url is not there
			if "https://en.wikipedia.org/w/" not in str(tag['href']):
				link.append(url+tag['href'])
			else:
				link.append(tag['href'])
				
	# Similarly check for heading
	# Six types of heading are there (H1, H2, H3, H4, H5, H6)
	# check each ta g and fetch text
	elif "h" in tag.name:
		if "h1"==tag.name:
			heading.append(tag.text)
		elif "h2"==tag.name:
			heading.append(tag.text)
		elif "h3"==tag.name:
			heading.append(tag.text)
		elif "h4"==tag.name:
			heading.append(tag.text)
		elif "h5"==tag.name:
			heading.append(tag.text)
		else:
			heading.append(tag.text)
			
	# Remain content will store here
	else:
		remaining_content.append(tag.text)
		
# print(paragraphs, images, link, heading, remaining_content)

for l in link:
    if 'Daftar_tokoh_agama_Indonesia/wiki/' in l:
        print(l)
# Out:
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Halaman_Utama
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Wikipedia:Isi
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Istimewa:Perubahan_terbaru
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Wikipedia:Artikel_pilihan/Topik
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Portal:Peristiwa_terkini
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Istimewa:Halaman_baru
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Istimewa:Halaman_sembarang
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Wikipedia:Warung_Kopi
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Portal:Komunitas
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Bantuan:Isi
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Wikipedia:Perihal
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Wikipedia:Pancapilar
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Wikipedia:Kebijakan_dan_pedoman
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Wikipedia:Hubungi_kami
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Wikipedia:Bak_pasir
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Halaman_Utama
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Istimewa:Pencarian
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Bantuan:Pengantar
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Istimewa:Kontribusi_saya
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Istimewa:Pembicaraan_saya
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Daftar_tokoh_agama_Indonesia
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Pembicaraan:Daftar_tokoh_agama_Indonesia
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Daftar_tokoh_agama_Indonesia
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Daftar_tokoh_agama_Indonesia
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Istimewa:Pranala_balik/Daftar_tokoh_agama_Indonesia
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Istimewa:Perubahan_terkait/Daftar_tokoh_agama_Indonesia
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Istimewa:Halaman_istimewa
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Indonesia
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/A.A._Yewangoe
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Abbas_Abdullah
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Abdul_Karim_Amrullah
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Abdullah_Gymnastiar
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Abdullah_Sungkar
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Abdurrahman_Wahid
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Abdus_Samad_al-Palimbani
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Agus_Salim
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Ahmad_Khatib_Al-Minangkabawi
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Ahmad_Rasyid_Sutan_Mansur
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Ahmad_Syafii_Maarif
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Ahmad_Wahib
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Abubakar_Ba%27asyir
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Ali_Yafie
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Andar_Lumbantobing
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Arrazy_Hasyim
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Ashin_Jinarakkhita
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Ashin_Kheminda
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Atimedho
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Azyumardi_Azra
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Bambang_Noorsena
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Burhanuddin_Ulakan
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Cittagutto
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Cornelis_Wowor
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Danghyang_Angsoka
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Danghyang_Astapaka
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Datuk_Ri_Bandang
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Dharmasurya_Bhumi
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Dick_Hartoko
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Din_Syamsuddin
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Djaulung_Wismar_Saragih_Sumbayak
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Djohan_Effendi
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Drijarkara
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/E.G._Singgih
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Eka_Darmaputera
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Franz_Magnis_Suseno
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Habib_Ali_Kwitang
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Haddad_Alwi
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Hamka
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Harun_Nasution
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Hasan_Basri_(MUI)
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Hasan_Mustapa
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Hasjim_Asy%27ari
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Hasyim_Muzadi
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Ibrahim_Musa
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Ignatius_Suharyo
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Ilyas_Ya%27kub
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/J._Drost
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Jayamedho
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Ja%E2%80%99far_Umar_Thalib
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Jinadhammo
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Jinakumari
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Julius_Darmaatmadja
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Khemanando
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Kholil_al-bangkalani
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Lia_Aminuddin
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Lutfiah_Sungkar
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Mahasthawira_Vajragiri
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Mahmoed_Joenoes
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Maimun_Zubair
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Achmad_Maryani_Ismail
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Malik_Ahmad
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Muhammad_Mahfudz_at-Tarmasi
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Mohammad_Natsir
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Mpu_Tantular
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Syeikh_Muhammad_Amrullah_Tuanku_Abdullah_Saleh
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Muhammad_Arifin_Ilham
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Muhammad_Arsyad_al-Banjari
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Syekh_Muhammad_Dalil_bin_Muhammad_Fatawi
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Muhammad_Imaduddin_Abdulrahim
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Muhammad_Isa_Anshary
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Muhammad_Jamil_Jambek
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Muhammad_Nafis_al-Banjari
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Syeikh_Muhammad_Saleh_Al-Minankabawi
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Syeikh_Tahir_Jalaluddin_Al-Azhari
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Muhammad_Thoha_Ma%27ruf
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Abuya_Muda_Waly
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Muhammad_Zaini_Abdul_Ghani
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Munzir_bin_Fuad_Al-Musawa
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Mustofa_Bisri
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Nawawi_al-Bantani
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Nur_Anas_Djamil
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Nurcholis_Madjid
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Oemar_Said_Tjokroaminoto
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/P.J._Zoetmulder
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Ragnar_Alm
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Raja_Ali_Haji
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/S.A.E._Nababan
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Sahal_Mahfudz
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Salahuddin_Wahid
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Salim_Segaf_Al-Jufri
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Sekarmadji_Maridjan_Kartosoewirjo
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Sindhunata
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Sirajuddin_Abbas
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Syeikh_Sulaiman_Ar-Rasuli
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Sumedha_Widyadharma
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Sunan_Giri
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Sutopo
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Syech_Yusuf_Tajul_Khalwati
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/T.B._Simatupang
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Tarmizi_Taher
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Thitayanno
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Tuanku_Imam_Bonjol
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Tuanku_Lintau
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Tuanku_Nan_Renceh
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Tuanku_Pasaman
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Tuanku_Rao
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Tuanku_Tambusai
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Uggadhammo
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Ulil_Abshar_Abdalla
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Uttamo
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Viriyanadi
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Wahyu_NH._Al_Aly
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Y.B.Mangunwijaya
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Syekh_Yasin_Al-Fadani
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Zainudin_M.Z
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Zainul_Arifin
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Tokoh_Islam_Indonesia
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Tokoh_Kristen_Indonesia
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Tokoh_Buddha_Indonesia
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Istimewa:Daftar_kategori
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Kategori:Daftar_tokoh_agama_Indonesia
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Wikipedia:Tentang
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Wikipedia:Penyangkalan_umum

# %%
for l in link:
    if 'Tokoh_' in l:
        print(l)
# Out:
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Tokoh_Islam_Indonesia
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Tokoh_Kristen_Indonesia
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/w/index.php?title=Tokoh_Katolik_Indonesia&action=edit&redlink=1
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/w/index.php?title=Tokoh_Hindu_Indonesia&action=edit&redlink=1
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/wiki/Tokoh_Buddha_Indonesia
# https://id.wikipedia.org/wiki/Daftar_tokoh_agama_Indonesia/w/index.php?title=Tokoh_aliran_kepercayaan_Indonesia&action=edit&redlink=1

# %%
import wikipedia

# %%
wikipedia.set_lang("id")

# %%
tii = wikipedia.page(title="Amien Rais")

tii.content
# Out:
# 'Prof. Dr. H. Muhammad Amien Rais, M.A., Ph.D. (lahir 26 April 1944) adalah politikus Indonesia yang saat ini menjabat sebagai Ketua Majelis Syuro Partai Ummat sejak awal dideklarasikan pada tanggal 29 April 2021. Selain itu, ia juga pernah menjabat sebagai Ketua Majelis Permusyawaratan Rakyat Republik Indonesia sejak 3 Oktober 1999 hingga 30 September 2004. Ia dikenal sebagai tokoh Muhammadiyah. Ia juga dikenal sebagai pendiri Partai Amanat Nasional dan pendiri Partai Ummat.\nNamanya mulai mencuat ke kancah perpolitikan Indonesia sebagai salah satu orang yang kritis terhadap kebijakan-kebijakan pemerintah menjelang berakhirnya kekuasaan Orde Baru di bawah Presiden Soeharto. Setelah partai-partai politik dihidupkan kembali pada masa pemerintahan Presiden B. J. Habibie, dirinya ikut mendeklarasikan pendirian Partai Amanat Nasional (PAN). Ia menjabat sebagai Ketua Umum PAN sejak partai tersebut berdiri sampai tahun 2005 dan tidak mencalonkan diri sebagai Ketua Umum di Kongres II.Amien menyatakan keluar dari partai besutannya itu, karena merasa PAN tidak sesuai lagi dengan asas dan gagasannya seperti dahulu. Ia bersama beberapa tokoh politik dan para loyalis beliau lainnya bersama pendukungnya di seluruh Indonesia, mendirikan organisasi politik baru bernama Partai Ummat pada tanggal 28 April 2021. Saat ini menjadi Ketua Majelis Syura Partai Ummat dan menujuk Dr. Ing. H. Ridho Rahmadi, S.Kom., M.Sc. sebagai Ketua Umum Dewan Pengurus Pusat Partai Ummat untuk periode awal.\n\n\n== Kehidupan pribadi ==\nLahir di Surakarta pada 26 April 1944, Amien dibesarkan dalam keluarga aktivis Muhammadiyah. Orangtuanya, aktif di Muhammadiyah cabang Surakarta, yakni ibunya Sudalmijah Suhud Rais yang menjabat sebagai Ketua Pimpinan Daerah Aisyiyah Surakarta sejak 1942 hingga 1952.Ia menikah dengan Kusnasriyati Sri Rahayu pada 1969. Dari pernikahannya, mereka dikaruniai lima orang anak, yaitu Ahmad Hanafi Rais, Hanum Salsabiela Rais, Ahmad Mumtaz Rais, Tasniem Fauzia Rais, dan Ahmad Baihaqi.Tanggal 8 Oktober 2011 putra Amien Rais, Ahmad Mumtaz Rais, menikah dengan Futri Zulya Safitri, putri dari Menteri Kehutanan, Zulkifli Hasan.\n\n\n== Karier awal ==\nSejak lulus sarjana dari Fakultas Ilmu Sosial dan Ilmu Politik, Universitas Gadjah Mada, Yogyakarta pada 1968 dan lulus Sarjana Muda Fakultas Tarbiyah UIN Sunan Kalijaga, Yogyakarta (1969) Amien melanglang ke berbagai negara dan baru kembali tahun 1984 dengan menggenggam gelar master (1974) dari Universitas Notre Dame, Indiana, Amerika Serikat dan gelar doktor ilmu politik dari Universitas Chicago, Illinois, Amerika Serikat.Amien kemudian menjadi seorang dosen pada Universitas Gadjah Mada. Ia bergiat pula dalam Muhammadiyah, ICMI, BPPT, dan beberapa organisasi lain.\n\n\n== Terjun ke politik ==\nAmien membentuk Partai Amanat Nasional (PAN) pada 1998 dengan platform nasionalis terbuka. Ketika hasil pemilu 1999 tidak memuaskan bagi PAN, Amien masih mampu berhasil menjadi Ketua MPR RI.Posisinya tersebut membuat peran Amien begitu besar dalam perjalanan politik Indonesia saat ini. Pada 1999, Amien urung maju dalam pemilihan presiden. Ia maju sebagai calon presiden bersama Siswono Yudo Husodo pada pilpres 2004, akan tetapi kalah dan hanya meraih kurang dari 15% suara nasional.Pada 2006 Amien turut mendukung evaluasi kontrak karya terhadap PT Freeport Indonesia. Setelah terjadi Peristiwa Abepura, Kepala Badan Intelijen Negara (BIN) Syamsir Siregar secara tidak langsung menuding Amien Rais dan LSM terlibat dibalik peristiwa ini. Tapi hal ini kemudian dibantah kembali oleh Syamsir Siregar.\nPada Mei 2007, Amien Rais mengakui bahwa semasa kampanye pemilihan umum presiden pada tahun 2004, ia menerima dana non bujeter Departemen Kelautan dan Perikanan dari Menteri Perikanan dan Kelautan, Rokhmin Dahuri sebesar Rp 200 juta. Ia sekaligus menuduh bahwa pasangan calon presiden dan wakil presiden lainnya turut menerima dana dari departemen tersebut, termasuk pasangan Susilo Bambang Yudhoyono dan Jusuf Kalla yang kem ...
