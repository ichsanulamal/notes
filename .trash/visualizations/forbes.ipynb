# %%
from pyforbes import ForbesList


flist = ForbesList()
df = flist.get_df("billionaires")

# %%
df
# Out:
#                 naturalId          name  year  month               uri  rank  \
# 0       faris/5/2024/4800  Billionaires  2024      4   bernard-arnault     1
# 1      faris/5/2024/14117  Billionaires  2024      4         elon-musk     2
# 2       faris/5/2024/6713  Billionaires  2024      4        jeff-bezos     3
# 3       faris/5/2024/8047  Billionaires  2024      4   mark-zuckerberg     4
# 4       faris/5/2024/5574  Billionaires  2024      4     larry-ellison     5
# ...                   ...           ...   ...    ...               ...   ...
# 2776  faris/5/2024/252300  Billionaires  2024      4        zhang-hong  2692
# 2777   faris/5/2024/13788  Billionaires  2024      4    zheng-xiaodong  2692
# 2778     faris/5/2024/207  Billionaires  2024      4  zhong-sheng-jian  2692
# 2779  faris/5/2024/203913  Billionaires  2024      4       zhou-junjie  2692
# 2780  faris/5/2024/233829  Billionaires  2024      4         zhu-yiwen  2692
#
#            listUri  visible  position  premiumProfile  ...  \
# 0     billionaires     True         1           False  ...
# 1     billionaires     True         2           False  ...
# 2     billionaires     True         3           False  ...
# 3     billionaires     True         4           False  ...
# 4     billionaires     True         5           False  ...
# ...            ...      ...       ...             ...  ...
# 2776  billionaires     True      2777           False  ...
# 2777  billionaires     True      2778           False  ...
# 2778  billionaires     True      2779           False  ...
# 2779  billionaires     True      2780           False  ...
# 2780  billionaires     True      2781           False  ...
#
#       numberOfSiblingsEst  thumbnail  recentEarnings assetsUnderManagement  \
# 0                     NaN        NaN             NaN                   NaN
# 1                     NaN        NaN             NaN                   NaN
# 2                     NaN        NaN             NaN                   NaN
# 3                     NaN        NaN             NaN                   NaN
# 4                     NaN        NaN             NaN                   NaN
# ...                   ...        ...             ...                   ...
# 2776                  NaN        NaN             NaN                   NaN
# 2777                  NaN        NaN             NaN                   NaN
# 2778                  NaN        NaN             NaN                   NaN
# 2779                  NaN        NaN             NaN                   NaN
# 2780                  NaN        NaN             NaN                   NaN
#
#       valueCreated notableDeal landscapeImage  portraitImage  \
# 0              NaN         NaN            NaN            NaN
# 1              NaN         NaN            NaN            NaN
# 2              NaN         NaN            NaN            NaN
# 3              NaN         NaN            NaN            NaN
# 4              NaN         NaN            NaN            NaN
# ...            ...         ...            ...            ...
# 2776           NaN         NaN            NaN            NaN
# 2777           NaN         NaN            NaN            NaN
# 2778           NaN         NaN            NaN            NaN
# 2779           NaN         NaN            NaN            NaN
# 2780           NaN         NaN            NaN            NaN
#
#      totalCharitableDonation charitableDonationPercentage
# 0                        NaN                          NaN
# 1                        NaN                          NaN
# 2                        NaN                          NaN
# 3                        NaN                          NaN
# 4                        NaN                          NaN
# ...                      ...                          ...
# 2776                     NaN                          NaN
# 2777                     NaN                          NaN
# 2778                     NaN                          NaN
# 2779                     NaN                          NaN
# 2780                     NaN                          NaN
#
# [2781 rows x 63 columns]

# %%
df.to_csv('ss.csv')

# %%
df[['uri', 'age', 'category', 'finalWorth', 'selfMadeRank']]
# Out:
#                    uri   age          category  finalWorth  selfMadeRank
# 0      bernard-arnault  75.0  Fashion & Retail    233000.0           NaN
# 1            elon-musk  52.0        Automotive    195000.0           8.0
# 2           jeff-bezos  60.0        Technology    194000.0           8.0
# 3      mark-zuckerberg  39.0        Technology    177000.0           8.0
# 4        larry-ellison  79.0        Technology    141000.0           9.0
# ...                ...   ...               ...         ...           ...
# 2776        zhang-hong   NaN            Energy      1000.0           NaN
# 2777    zheng-xiaodong  60.0     Manufacturing      1000.0           NaN
# 2778  zhong-sheng-jian  66.0       Real Estate      1000.0           NaN
# 2779       zhou-junjie  55.0     Manufacturing      1000.0           NaN
# 2780         zhu-yiwen  60.0        Healthcare      1000.0           NaN
#
# [2781 rows x 5 columns]

# %%
python bubble chart, with the bubble size is 'finalWorth' of 'name'. x axis is 'age', and color it with 'category'

# %%
import plotly.express as px
import pandas as pd

# Create the packed bubble chart
fig = px.scatter(df, 
                 x='age', 
                 y='finalWorth',  # Dummy y-axis since plotly does not directly support packed bubbles
                 size='finalWorth', 
                 color='category', 
                 hover_name='uri', 
                 size_max=60,
                 title='Packed Bubble Chart of Final Worth by Age and Category')

# Customize the layout to hide the dummy y-axis
# fig.update_layout(yaxis=dict(showticklabels=False, showgrid=False, zeroline=False))

# Show the plot
fig.show()

# %%
import plotly.express as px
import pandas as pd

# Create the packed bubble chart
fig = px.scatter(df, 
                 x='age', 
                 y='selfMadeRank',  # Dummy y-axis since plotly does not directly support packed bubbles
                 size='finalWorth', 
                 color='category', 
                 hover_name='uri', 
                 size_max=60,
                 title='Packed Bubble Chart of Final Worth by Age and Self Made Score')

# Customize the layout to hide the dummy y-axis
# fig.update_layout(yaxis=dict(showticklabels=False, showgrid=False, zeroline=False))

# Show the plot
fig.show()

# %%
import plotly.express as px
import pandas as pd

# Create the packed bubble chart
fig = px.scatter(df, 
                 x='age', 
                 y='finalWorth',  # Dummy y-axis since plotly does not directly support packed bubbles
                 size='finalWorth', 
                 color='country', 
                 hover_name='uri', 
                 size_max=60,
                 title='Packed Bubble Chart of Final Worth by Age and Country')

# Customize the layout to hide the dummy y-axis
fig.update_layout(yaxis=dict(showticklabels=False, showgrid=False, zeroline=False))

# Show the plot
fig.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Sort the DataFrame by 'finalWorth'
df = df.sort_values('finalWorth', ascending=False)
df

# Create the bar plot
plt.figure(figsize=(10, 6))
bar_plot = sns.barplot(
    x='finalWorth', 
    y='uri', 
    data=df.head(25), 
    hue='category',
    dodge=False
)

# Customize the plot
bar_plot.set_title('Bar Chart of Final Worth Sorted by Final Worth')
bar_plot.set_xlabel('Final Worth')
bar_plot.set_ylabel('Name')

# Show the plot
plt.legend(title='Category')
plt.show()

# %%
df[df['country'] == 'Indonesia'][['uri', 'finalWorth', 'category']]
# Out:
#                                uri  finalWorth               category
# 26                prajogo-pangestu     43400.0            Diversified
# 65                  low-tuck-kwong     27400.0                 Energy
# 70                  r-budi-hartono     26500.0  Finance & Investments
# 76                 michael-hartono     25500.0          Manufacturing
# 507             agoes-projosasmito      5900.0        Metals & Mining
# 561                chairul-tanjung      5500.0            Diversified
# 658                          tahir      4800.0            Diversified
# 701                       dewi-kam      4500.0                 Energy
# 782                  djoko-susanto      4100.0       Fashion & Retail
# 795   lim-hariyanto-wijaya-sarwono      4000.0        Metals & Mining
# 1053              theodore-rachmat      3200.0            Diversified
# 1223              alexander-ramlie      2800.0        Metals & Mining
# 1603                 peter-sondakh      2100.0  Finance & Investments
# 1606               hermanto-tanoko      2100.0          Manufacturing
# 1745                 manoj-punjabi      1900.0  Media & Entertainment
# 1751              bambang-sutantio      1900.0        Food & Beverage
# 1838              otto-toto-sugiri      1800.0             Technology
# 1944         soegiarto-adikoesoemo      1600.0              Logistics
# 2160                    kiki-barki      1400.0                 Energy
# 2223                 lim-chai-hock      1400.0                 Energy
# 2247                 mochtar-riady      1400.0            Diversified
# 2374                 eddy-sugianto      1300.0        Metals & Mining
# 2381       haryanto-tjiptodihardjo      1300.0          Manufacturing
# 2444            wirastuty-fangiono      1200.0          Manufacturing
# 2502                   murdaya-poo      1200.0            Diversified
# 2656                benny-suherman      1100.0  Media & Entertainment
# 2697                marina-budiman      1000.0             Technology
# 2757           edwin-soeryadjaya-1      1000.0                 Energy
# 2760                 wijono-tanoko      1000.0          Manufacturing

# %%
# Calculate the count of entries by country
country_counts = df['country'].value_counts().reset_index().head(20)
country_counts.columns = ['country', 'count']

# Create the bar plot
plt.figure(figsize=(12, 8))
bar_plot = sns.barplot(
    x='count', 
    y='country', 
    data=country_counts,
    palette='viridis'
)

# Customize the plot
bar_plot.set_title('Count of Entries by Country')
bar_plot.set_xlabel('Count')
bar_plot.set_ylabel('Country')

for index, value in enumerate(country_counts['count']):
    bar_plot.text(value, index, f'{value}', va='center')

# Show the plot
plt.show()
# Out:
# /tmp/ipykernel_16723/3263852445.py:7: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %%
# Calculate the sum of 'totalWorth' by 'country'
country_total_worth = df.groupby('country')['finalWorth'].sum().reset_index()

# Sort the data for better visualization (optional)
country_total_worth = country_total_worth.sort_values(by='finalWorth', ascending=False).head(20)

# Create the bar plot
plt.figure(figsize=(12, 8))
bar_plot = sns.barplot(
    x='finalWorth', 
    y='country', 
    data=country_total_worth,
    palette='viridis'
)

# Customize the plot
bar_plot.set_title('Sum of Total Worth by Country')
bar_plot.set_xlabel('Total Worth')
bar_plot.set_ylabel('Country')

# Add the total worth numbers beside the bars
for index, value in enumerate(country_total_worth['finalWorth']):
    bar_plot.text(value, index, f'{value:,.0f}', va='center')

# Show the plot
plt.show()
# Out:
# /tmp/ipykernel_16723/170579669.py:9: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
