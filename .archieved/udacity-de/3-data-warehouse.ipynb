# %%
# !pip install psycopg2-binary
# !pip install !python-sql
# !pip install pandas

# %% [markdown]
# Run this to import data to psql
#
#
# ```
# psql -U postgres -d pagila -a -f data-sample\pagila-0.10.1\pagila-schema.sql
# psql -U postgres -d pagila -a -f data-sample\pagila-0.10.1\pagila-insert-data.sql
# psql -U postgres -d pagila -a -f data-sample\pagila-0.10.1\pagila-data.sql
# ```

# %%
# %load_ext sql

# %%
DB_ENDPOINT = 'localhost'
DB = 'pagila'
DB_USER = 'postgres'
DB_PASSWORD = 'postgres'
DB_PORT = '5432'

conn_string = 'postgresql://{}:{}@{}:{}/{}'.format(DB_USER, DB_PASSWORD, DB_ENDPOINT, DB_PORT, DB)

# %%
# %sql $conn_string
# Out:
# 'Connected: postgres@pagila'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# %%sql
# SELECT DISTINCT f.title, CONCAT(a.first_name, ' ', a.last_name)
# FROM film_actor fa
# JOIN film f ON fa.film_id =f.film_id
# JOIN actor a ON fa.actor_id = a.actor_id
# LIMIT 10
# Out:
#    postgresql://postgres:***@localhost:5432
#  * postgresql://postgres:***@localhost:5432/pagila
# 10 rows affected.
# [('FLATLINERS KILLER', 'MORGAN HOPKINS'),
#  ('LEGALLY SECRETARY', 'HELEN VOIGHT'),
#  ('EVE RESURRECTION', 'GENE MCKELLEN'),
#  ('UNTOUCHABLES SUNRISE', 'PENELOPE CRONYN'),
#  ('DOZEN LION', 'NATALIE HOPKINS'),
#  ('MAGNOLIA FORRESTER', 'GROUCHO SINATRA'),
#  ('WEST LION', 'CARY MCCONAUGHEY'),
#  ('CAMPUS REMEMBER', 'MATTHEW JOHANSSON'),
#  ('DAWN POND', 'SCARLETT DAMON'),
#  ('PINOCCHIO SIMON', 'REESE KILMER')]

# %% [markdown]
# # TODO
#
# BUILD DWH BASED ON THAT DATA
