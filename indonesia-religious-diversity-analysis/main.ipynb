# %%
pip install pandas requests beautifulsoup4 spacy

python -m spacy download xx_ent_wiki_sm

# python -m spacy download en_core_web_sm

# %%
import pandas as pd

# %%
df = pd.DataFrame()

# %%
import requests
from bs4 import BeautifulSoup

# Make a request to the webpage
url = 'https://nasional.kompas.com/read/2017/11/07/18102221/di-sidang-mk-peneliti-lipi-nilai-ahmadiyah-tak-bisa-dianggap-sesat?page=all'  # Replace with the actual URL
response = requests.get(url)

# Parse the HTML content
soup = BeautifulSoup(response.content, 'html.parser')

# Initialize an empty dictionary
scraped_data = {}

scraped_data['title'] = soup.find(class_='read__title').text
scraped_data['topic_subtitle'] = soup.select_one('.topicSubtitle ul li a').text
scraped_data['read_time'] = soup.select_one('.read__time')
scraped_data['writers'] = [h6.text for h6 in soup.select('.credit-title-name')]
scraped_data['read_content'] = '\n'.join(p.text for p in soup.select('.read__content p'))

# %%
# Convert the dictionary to a Pandas DataFrame
df = pd.DataFrame([scraped_data])

# %%
df.to_csv('scraped_data.csv', index=False)

# %% [markdown]
# # Extract Entity

# %%
import spacy

# Load the Indonesian model for spaCy
nlp = spacy.load('xx_ent_wiki_sm')  # This is the small Indonesian model

# Assuming 'read_content' is the variable containing the scraped content
doc = nlp(scraped_data['read_content'])

# Extract entities
entities = [(ent.text, ent.label_) for ent in doc.ents]

# %%
s = set()
for entity in entities.:
    s.add(entity[0] + "|" + entity[1])

# %%
for i in s:
    print(i)
# Out:
# Ghulam Ahmad|PER
# Surat|LOC
# Qadian|PER
# NU|LOC
# PNPS|ORG
# Sebelumnya|LOC
# Alami Kekerasan|PER
# ini memang|ORG
# hitungan hari|PER
# Berdasarkan pengalaman itu|MISC
# Selanjutnya|LOC
# Maret1953|MISC
# Nilai Negara|PER
# RI|ORG
# Upaya|LOC
# MK|ORG
# Apakah Ghulam Ahmad|PER
# Saya|PER
# Baitullah di Mekkah|PER
# yang justru|PER
# India|LOC
# Kesalahpahaman|PER
# Sawangan|LOC
# penelitian yang ia lakukan|PER
# Terus|PER
# SKB Ahmadiyah|ORG
# Ahmad Najib Burhani|PER
# JAI|MISC
# Nabi Muhammad|PER
# pun|ORG
# RI Nomor|MISC
# Depok|LOC
# Pencegahan Penyalahgunaan|PER
# Jalan Muchtar Raya|PER
# Penetapan Presiden|MISC
# Informasi PP Muhammadiyah|PER
# Baca|PER
# Islam|MISC
# Komnas HAM|MISC
# Undang-Undang Nomor|LOC
# Anggota|PER
# SKB Tiga Menteri|ORG
# Al Quran|PER
# P3A|MISC
# PNPS/1965|LOC
# Keputusan Menteri Kehakiman|PER
# Masjid Al Aqsa|PER
# Ahmadiyah|PER
# Bahkan|LOC
# saya ingin menunjukkan|PER
# Jamaah Ahmadiyah|PER
# LIPI|ORG
# Abdurrahman Wahid|PER
# PNPS Tahun|MISC
# NU|PER
# Penodaan Agama|LOC
# Undang-Undang Penodaan Agama|LOC
# JAKARTA|MISC
# Mirza Ghulam Ahmad|PER
# Untuk|PER
# Jemaah Ahmadiyah|PER
# yang tidak benar|PER
# Badan|PER
# Peringatan|LOC
# Ahmad|PER
# Namun|PER
# Pasal 1|MISC
# Keputusan Bersama|PER
# SKB|ORG
# Wakil Ketua Majelis Pustaka|LOC
# Warga Ahmadiyah Manislor|PER
# Masjid Al Hidayah|PER
# Lembaga Ilmu Pengetahuan Indonesia|PER
# Senin|LOC
# Indonesia|LOC
# Sidang MK|MISC
# Perintah|MISC
# YLBHI|ORG
# Penganut|LOC
# Kompas.com/Alsadad Rudi Pelang|PER
# Pemerintah Kota Depok|PER
# yang jelas|PER
# hal yang kurang pas|PER
# Tazkirah|PER
# Putusan Pengadilan|PER
# Saya mengamati|PER
# Mahkamah Konstitusi|PER
# Nomor J.A.|PER
# Ahmadiyah di|PER
# Anggota Pengurus JAI|MISC
# Qadian|LOC
# Masjid Mubarak|PER
# Gus Dur|PER
# Ahmadiyah|LOC
# Sanjungan|PER
# Baca|LOC
# Tambahan Berita Negara|ORG
# Jakarta Pusat|PER
# Diskriminasi Berlapis|PER

# %% [markdown]
# # Pagination

# %%
import requests
from bs4 import BeautifulSoup

# Define the base URL and search parameters
base_url = 'https://search.kompas.com/search/?q=FPI&submit=Submit#gsc.tab=0&gsc.q=FPI'
params = {'gsc.page': '1'}

# Create a list to store the scraped data
scraped_data = []

# Function to scrape a single page
def scrape_page(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Extract data from the page (adjust as per your specific case)
    # For example, if you're scraping a list of products, you would locate the elements here
    # and append them to the `scraped_data` list.

    # For demonstration, let's assume you're scraping titles from a list of items
    titles = [item.text for item in soup.find_all('h2', class_='item-title')]
    scraped_data.extend(titles)

# Start by sending a search request
response = requests.get(base_url, params=params)
soup = BeautifulSoup(response.content, 'html.parser')

# Process the first page
scrape_page(response.url)

# %%
from bs4 import BeautifulSoup
import requests 

url = 'https://indeks.kompas.com/?site=all&date=2023-11-03&page=1'
req = requests.get(url)

# print(req.text)

soup = BeautifulSoup(req.text, 'lxml')

a = soup.find_all('a',{'class':'article__link'})

kumpulan_link = []
kumpulan_paragraf = []

for link in a: 
    kumpulan_link.append(link['href'])

for link in kumpulan_link:
    halaman = requests.get(link)
    soup_baru = BeautifulSoup(halaman.text,'lxml')
    paragraf = soup_baru.find_all('p')
    for kalimat in paragraf: 
        kumpulan_paragraf.append(kalimat.text)

with open('paragraf.txt', 'a') as f: 
    for paragraf in kumpulan_paragraf: 
        print('penulisan berhasil')
        f.writelines(paragraf + '\n')
# Out:
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
# penulisan berhasil
